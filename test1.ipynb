# %% [markdown]
# <a href="https://colab.research.google.com/github/Tay25006739/data-science-toolkit/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import kagglehub
import os

# Download latest version
path = kagglehub.dataset_download("ahmeduzaki/global-earthquake-tsunami-risk-assessment-dataset")

print("Path to dataset files:", path)

# List files in the downloaded directory to find the correct filename
file_list = os.listdir(path)
print("Files in the downloaded directory:", file_list)

# Assuming the relevant CSV file is the first one in the list, adjust if necessary
csv_file_path = os.path.join(path, file_list[0])

df = pd.read_csv(csv_file_path)
display(df.head())

print("done")
# Out:
# Using Colab cache for faster access to the 'global-earthquake-tsunami-risk-assessment-dataset' dataset.
# Path to dataset files: /kaggle/input/global-earthquake-tsunami-risk-assessment-dataset
# Files in the downloaded directory: ['earthquake_data_tsunami.csv']
#    magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1        6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2        7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3        7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4        6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# 3  2022     11        1
# 4  2022     11        1
# done
